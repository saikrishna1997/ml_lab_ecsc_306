# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[0],[0],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for AND GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  1.26079
# iteration=  1000 cost=  0.519552
# iteration=  2000 cost=  0.388627
# iteration=  3000 cost=  0.315298
# iteration=  4000 cost=  0.267935
# iteration=  5000 cost=  0.234157
# iteration=  6000 cost=  0.208459
# iteration=  7000 cost=  0.188052
# iteration=  8000 cost=  0.171357
# iteration=  9000 cost=  0.157399
# iteration=  10000 cost=  0.145531
# iteration=  11000 cost=  0.135305
# iteration=  12000 cost=  0.126396
# Validating output for AND GATE
# [[ 0.00563295]
#  [ 0.13523743]
#  [ 0.1332071 ]
#  [ 0.80925173]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for OR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  0.423206
# iteration=  1000 cost=  0.314355
# iteration=  2000 cost=  0.246763
# iteration=  3000 cost=  0.202077
# iteration=  4000 cost=  0.170649
# iteration=  5000 cost=  0.147398
# iteration=  6000 cost=  0.129516
# iteration=  7000 cost=  0.115348
# iteration=  8000 cost=  0.103857
# iteration=  9000 cost=  0.0943583
# iteration=  10000 cost=  0.0863841
# iteration=  11000 cost=  0.0796004
# iteration=  12000 cost=  0.0737641
# Validating output for OR GATE
# [[ 0.15537894]
#  [ 0.93653703]
#  [ 0.94192171]
#  [ 0.99923193]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

#weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
#bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



#multiply1=tf.add(tf.matmul(x,weights),bias)
#z=tf.nn.sigmoid(multiply1)


Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x, Theta1) + Bias1)
z = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
    
cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[0]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(100000):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration = ",i,"cost= ",res)
    print ("Validating output for XOR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration =  0 cost=  0.698061
# iteration =  1000 cost=  0.693342
# iteration =  2000 cost=  0.691901
# iteration =  3000 cost=  0.69042
# iteration =  4000 cost=  0.688774
# iteration =  5000 cost=  0.686838
# iteration =  6000 cost=  0.684487
# iteration =  7000 cost=  0.68159
# iteration =  8000 cost=  0.678011
# iteration =  9000 cost=  0.673611
# iteration =  10000 cost=  0.668241
# iteration =  11000 cost=  0.661746
# iteration =  12000 cost=  0.653969
# iteration =  13000 cost=  0.64477
# iteration =  14000 cost=  0.634059
# iteration =  15000 cost=  0.621838
# iteration =  16000 cost=  0.608211
# iteration =  17000 cost=  0.593364
# iteration =  18000 cost=  0.577507
# iteration =  19000 cost=  0.560785
# iteration =  20000 cost=  0.543204
# iteration =  21000 cost=  0.524588
# iteration =  22000 cost=  0.504572
# iteration =  23000 cost=  0.482653
# iteration =  24000 cost=  0.458302
# iteration =  25000 cost=  0.431145
# iteration =  26000 cost=  0.401171
# iteration =  27000 cost=  0.368911
# iteration =  28000 cost=  0.335438
# iteration =  29000 cost=  0.302146
# iteration =  30000 cost=  0.270377
# iteration =  31000 cost=  0.241139
# iteration =  32000 cost=  0.214978
# iteration =  33000 cost=  0.192028
# iteration =  34000 cost=  0.172138
# iteration =  35000 cost=  0.15501
# iteration =  36000 cost=  0.140288
# iteration =  37000 cost=  0.127621
# iteration =  38000 cost=  0.116689
# iteration =  39000 cost=  0.107215
# iteration =  40000 cost=  0.0989649
# iteration =  41000 cost=  0.0917427
# iteration =  42000 cost=  0.0853873
# iteration =  43000 cost=  0.0797655
# iteration =  44000 cost=  0.0747675
# iteration =  45000 cost=  0.0703029
# iteration =  46000 cost=  0.0662962
# iteration =  47000 cost=  0.0626848
# iteration =  48000 cost=  0.0594166
# iteration =  49000 cost=  0.0564475
# iteration =  50000 cost=  0.0537402
# iteration =  51000 cost=  0.0512635
# iteration =  52000 cost=  0.0489902
# iteration =  53000 cost=  0.0468973
# iteration =  54000 cost=  0.0449657
# iteration =  55000 cost=  0.0431775
# iteration =  56000 cost=  0.041518
# iteration =  57000 cost=  0.0399745
# iteration =  58000 cost=  0.0385358
# iteration =  59000 cost=  0.0371915
# iteration =  60000 cost=  0.0359333
# iteration =  61000 cost=  0.0347533
# iteration =  62000 cost=  0.0336448
# iteration =  63000 cost=  0.0326009
# iteration =  64000 cost=  0.0316176
# iteration =  65000 cost=  0.0306887
# iteration =  66000 cost=  0.0298108
# iteration =  67000 cost=  0.0289796
# iteration =  68000 cost=  0.0281921
# iteration =  69000 cost=  0.0274439
# iteration =  70000 cost=  0.026733
# iteration =  71000 cost=  0.0260567
# iteration =  72000 cost=  0.0254123
# iteration =  73000 cost=  0.0247978
# iteration =  74000 cost=  0.0242112
# iteration =  75000 cost=  0.0236504
# iteration =  76000 cost=  0.023114
# iteration =  77000 cost=  0.0226006
# iteration =  78000 cost=  0.0221095
# iteration =  79000 cost=  0.0216384
# iteration =  80000 cost=  0.0211853
# iteration =  81000 cost=  0.0207506
# iteration =  82000 cost=  0.0203329
# iteration =  83000 cost=  0.0199314
# iteration =  84000 cost=  0.0195448
# iteration =  85000 cost=  0.0191726
# iteration =  86000 cost=  0.0188131
# iteration =  87000 cost=  0.0184678
# iteration =  88000 cost=  0.0181332
# iteration =  89000 cost=  0.0178111
# iteration =  90000 cost=  0.0174993
# iteration =  91000 cost=  0.0171984
# iteration =  92000 cost=  0.016907
# iteration =  93000 cost=  0.016625
# iteration =  94000 cost=  0.0163526
# iteration =  95000 cost=  0.0160878
# iteration =  96000 cost=  0.0158318
# iteration =  97000 cost=  0.0155838
# iteration =  98000 cost=  0.0153433
# iteration =  99000 cost=  0.0151094
# Validating output for XOR GATE
# [[ 0.01753363]
#  [ 0.98654872]
#  [ 0.98654675]
#  [ 0.01464619]]

# %%
import tensorflow as tf
x_ = tf.placeholder(tf.float32, shape=[4,2], name="x-input")
y_ = tf.placeholder(tf.float32, shape=[4,1], name="y-input")
Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)
Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
for i in range(100000):
        sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})

        
if i % 1000 == 0:
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
